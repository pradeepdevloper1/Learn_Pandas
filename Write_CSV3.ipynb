# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\Learning\\Pandas\\Companies.csv')
df
# Out:
#    ID             Name            Industry  Inception    Revenue  \
# 0   1          Lamtone         IT Services       2009  $11757018
# 1   2        Stripfind  Financial Services       2010  $12329371
# 2   3  CaneCorporation     Health Services       2012  $10597009
# 3   4         MatTouch         IT Services       2013  $14026934
# 4   5        TechDrill  Financial Services       2009  $11757018
# 5   6         TechLine  Financial Services       2006  $12329371
# 6   7          CityAce  Financial Services       2010  $11757018
# 7   8   KeyElectronics  Financial Services       2009  $12329371
# 8   9          Ganzlax  Financial Services       2011  $11757018
# 9   9       TranTaxlax  Financial Services       2011  $12329371
#
#           Expenses    Profit Growth
# 0  6482465 Dollars   5274553    30%
# 1   916455 Dollars  11412916    20%
# 2  7591189 Dollars   6597557     7%
# 3  7429377 Dollars   3138627    26%
# 4   916455 Dollars  11412916     8%
# ...

# %%
df.head()
# Out:
#    ID             Name            Industry  Inception    Revenue  \
# 0   1          Lamtone         IT Services       2009  $11757018
# 1   2        Stripfind  Financial Services       2010  $12329371
# 2   3  CaneCorporation     Health Services       2012  $10597009
# 3   4         MatTouch         IT Services       2013  $14026934
# 4   5        TechDrill  Financial Services       2009  $11757018
#
#           Expenses    Profit Growth
# 0  6482465 Dollars   5274553    30%
# 1   916455 Dollars  11412916    20%
# 2  7591189 Dollars   6597557     7%
# 3  7429377 Dollars   3138627    26%
# 4   916455 Dollars  11412916     8%

# %%
df.tail()
# Out:
#    ID            Name            Industry  Inception    Revenue  \
# 5   6        TechLine  Financial Services       2006  $12329371
# 6   7         CityAce  Financial Services       2010  $11757018
# 7   8  KeyElectronics  Financial Services       2009  $12329371
# 8   9         Ganzlax  Financial Services       2011  $11757018
# 9   9      TranTaxlax  Financial Services       2011  $12329371
#
#           Expenses    Profit Growth
# 5  6482465 Dollars  11412916    23%
# 6   916455 Dollars  11412916     6%
# 7  6482465 Dollars  11412916     4%
# 8   916455 Dollars  11412916    18%
# 9  6482465 Dollars  11412916     7%

# %%
df.head(7)
# Out:
#    ID             Name            Industry  Inception    Revenue  \
# 0   1          Lamtone         IT Services       2009  $11757018
# 1   2        Stripfind  Financial Services       2010  $12329371
# 2   3  CaneCorporation     Health Services       2012  $10597009
# 3   4         MatTouch         IT Services       2013  $14026934
# 4   5        TechDrill  Financial Services       2009  $11757018
# 5   6         TechLine  Financial Services       2006  $12329371
# 6   7          CityAce  Financial Services       2010  $11757018
#
#           Expenses    Profit Growth
# 0  6482465 Dollars   5274553    30%
# 1   916455 Dollars  11412916    20%
# 2  7591189 Dollars   6597557     7%
# 3  7429377 Dollars   3138627    26%
# 4   916455 Dollars  11412916     8%
# 5  6482465 Dollars  11412916    23%
# 6   916455 Dollars  11412916     6%

# %%
df.tail(7)
# Out:
#    ID            Name            Industry  Inception    Revenue  \
# 3   4        MatTouch         IT Services       2013  $14026934
# 4   5       TechDrill  Financial Services       2009  $11757018
# 5   6        TechLine  Financial Services       2006  $12329371
# 6   7         CityAce  Financial Services       2010  $11757018
# 7   8  KeyElectronics  Financial Services       2009  $12329371
# 8   9         Ganzlax  Financial Services       2011  $11757018
# 9   9      TranTaxlax  Financial Services       2011  $12329371
#
#           Expenses    Profit Growth
# 3  7429377 Dollars   3138627    26%
# 4   916455 Dollars  11412916     8%
# 5  6482465 Dollars  11412916    23%
# 6   916455 Dollars  11412916     6%
# 7  6482465 Dollars  11412916     4%
# 8   916455 Dollars  11412916    18%
# 9  6482465 Dollars  11412916     7%

# %%
df=pd.read_csv('D:\\Learning\\Pandas\\Companies.csv',dtype={'ID':'float64','Profit':'float64'})
df
# Out:
#     ID             Name            Industry  Inception    Revenue  \
# 0  1.0          Lamtone         IT Services       2009  $11757018
# 1  2.0        Stripfind  Financial Services       2010  $12329371
# 2  3.0  CaneCorporation     Health Services       2012  $10597009
# 3  4.0         MatTouch         IT Services       2013  $14026934
# 4  5.0        TechDrill  Financial Services       2009  $11757018
# 5  6.0         TechLine  Financial Services       2006  $12329371
# 6  7.0          CityAce  Financial Services       2010  $11757018
# 7  8.0   KeyElectronics  Financial Services       2009  $12329371
# 8  9.0          Ganzlax  Financial Services       2011  $11757018
# 9  9.0       TranTaxlax  Financial Services       2011  $12329371
#
#           Expenses      Profit Growth
# 0  6482465 Dollars   5274553.0    30%
# 1   916455 Dollars  11412916.0    20%
# 2  7591189 Dollars   6597557.0     7%
# 3  7429377 Dollars   3138627.0    26%
# 4   916455 Dollars  11412916.0     8%
# ...

# %%
df=pd.read_csv('D:\\Learning\\Pandas\\Companies.csv')
df
# Out:
#    ID Date             Name            Industry  Inception    Revenue  \
# 0   1  Yes          Lamtone         IT Services       2009  $11757018
# 1   2   No        Stripfind  Financial Services       2010  $12329371
# 2   3  Yes  CaneCorporation     Health Services       2012  $10597009
# 3   4   No         MatTouch         IT Services       2013  $14026934
# 4   5  Yes        TechDrill  Financial Services       2009  $11757018
# 5   6   No         TechLine  Financial Services       2006  $12329371
# 6   7  Yes          CityAce  Financial Services       2010  $11757018
# 7   8   No   KeyElectronics  Financial Services       2009  $12329371
# 8   9  Yes          Ganzlax  Financial Services       2011  $11757018
# 9   9   No       TranTaxlax  Financial Services       2011  $12329371
#
#           Expenses    Profit Growth
# 0  6482465 Dollars   5274553    30%
# 1   916455 Dollars  11412916    20%
# 2  7591189 Dollars   6597557     7%
# 3  7429377 Dollars   3138627    26%
# ...

# %%
df=pd.read_csv('D:\\Learning\\Pandas\\Companies.csv',true_values=['Yes'],false_values=['No'])
df
# Out:
#    ID   Date             Name            Industry  Inception    Revenue  \
# 0   1   True          Lamtone         IT Services       2009  $11757018
# 1   2  False        Stripfind  Financial Services       2010  $12329371
# 2   3   True  CaneCorporation     Health Services       2012  $10597009
# 3   4  False         MatTouch         IT Services       2013  $14026934
# 4   5   True        TechDrill  Financial Services       2009  $11757018
# 5   6  False         TechLine  Financial Services       2006  $12329371
# 6   7   True          CityAce  Financial Services       2010  $11757018
# 7   8  False   KeyElectronics  Financial Services       2009  $12329371
# 8   9   True          Ganzlax  Financial Services       2011  $11757018
# 9   9  False       TranTaxlax  Financial Services       2011  $12329371
#
#           Expenses    Profit Growth
# 0  6482465 Dollars   5274553    30%
# 1   916455 Dollars  11412916    20%
# 2  7591189 Dollars   6597557     7%
# ...
